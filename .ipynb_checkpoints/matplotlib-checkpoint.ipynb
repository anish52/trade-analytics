# %%
# %load_ext autotime
# Out:
# time: 574 µs (started: 2022-05-29 02:25:17 -07:00)

# %%
from utils.get_data import stock_metrics
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.image as mpimg
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox


plt.style.use('dark_background')
# %matplotlib inline
# Out:
# time: 4.95 s (started: 2022-05-29 02:25:18 -07:00)

# %%
df, stock_list = stock_metrics()
# Out:
# time: 19.9 s (started: 2022-05-29 02:25:23 -07:00)

# %%
r1 = patches.Rectangle((2, 26),width=24,height=24,fill=True,facecolor='black',linewidth=2,edgecolor='white')
r2 = patches.Rectangle((4, 4),width=20,height=20,fill=True,facecolor='black',linewidth=2,edgecolor='white')
r3 = patches.Rectangle((24, 12),width=12,height=12,fill=True,facecolor='black',linewidth=2,edgecolor='white')
r4 = patches.Rectangle((24, 4),width=12,height=8,fill=True,facecolor='black',linewidth=2,edgecolor='white')

r5 = patches.Rectangle((40, 40),width=20,height=20,fill=True,facecolor='black',linewidth=2,edgecolor='white')
r6 = patches.Rectangle((40, 28),width=12,height=12,fill=True,facecolor='black',linewidth=2,edgecolor='white')
r7 = patches.Rectangle((52, 28),width=8,height=12,fill=True,facecolor='black',linewidth=2,edgecolor='white')

r8 = patches.Rectangle((40, 4),width=12,height=12,fill=True,facecolor='black',linewidth=2,edgecolor='white')
r9 = patches.Rectangle((52, 4),width=8,height=12,fill=True,facecolor='black',linewidth=2,edgecolor='white')

r10 = patches.Rectangle((64, 44),width=10,height=12,fill=True,facecolor='black',linewidth=2,edgecolor='white')
r11 = patches.Rectangle((76, 44),width=8,height=12,fill=True,facecolor='black',linewidth=2,edgecolor='white')

r12 = patches.Rectangle((64, 16),width=20,height=20,fill=True,facecolor='black',linewidth=2,edgecolor='white')
r13 = patches.Rectangle((64, 4),width=12,height=12,fill=True,facecolor='black',linewidth=2,edgecolor='white')
r14 = patches.Rectangle((76, 4),width=8,height=12,fill=True,facecolor='black',linewidth=2,edgecolor='white')
# Out:
# time: 8.69 ms (started: 2022-05-28 19:41:48 -07:00)

# %%
i1 = AnnotationBbox(OffsetImage(mpimg.imread('./images/apple.png'), zoom=1), (20, 45))
i2 = AnnotationBbox(OffsetImage(mpimg.imread('./images/nvidia.png'), zoom=1), (14, 18))
i3 = AnnotationBbox(OffsetImage(mpimg.imread('./images/intel.png'), zoom=1), (30, 21))
i4 = AnnotationBbox(OffsetImage(mpimg.imread('./images/qualcomm.png'), zoom=1), (30, 10.5))

i5 = AnnotationBbox(OffsetImage(mpimg.imread('./images/microsoft.png'), zoom=0.6), (50, 50))
i6 = AnnotationBbox(OffsetImage(mpimg.imread('./images/google.png'), zoom=0.6), (46, 33))
i7 = AnnotationBbox(OffsetImage(mpimg.imread('./images/meta2.png'), zoom=1.25), (56, 33))

i8 = AnnotationBbox(OffsetImage(mpimg.imread('./images/amazon.png'), zoom=0.7), (46, 13))
i9 = AnnotationBbox(OffsetImage(mpimg.imread('./images/walmart.jpeg'), zoom=0.6), (56, 13))

i10 = AnnotationBbox(OffsetImage(mpimg.imread('./images/tesla.png'), zoom=0.5), (70, 52))
i11 = AnnotationBbox(OffsetImage(mpimg.imread('./images/ea.png'), zoom=0.4), (80, 52))

i12 = AnnotationBbox(OffsetImage(mpimg.imread('./images/uhg.png'), zoom=0.9), (74, 30.5))
i13 = AnnotationBbox(OffsetImage(mpimg.imread('./images/azn.png'), zoom=0.6), (70, 13))
i14 = AnnotationBbox(OffsetImage(mpimg.imread('./images/cvs.png'), zoom=0.8), (80, 13))
# Out:
# time: 390 ms (started: 2022-05-28 19:41:48 -07:00)

# %%
def get_color(x):
    return 'g' if df.loc[x]['percentage_change']>=0 else 'r'
# Out:
# time: 1.03 ms (started: 2022-05-28 19:41:48 -07:00)

# %%
r = [r1,r2,r3,r4,r5,r6,r7,r8,r9,r10,r11,r12,r13,r14]
i = [i1,i2,i3,i4,i5,i6,i7,i8,i9,i10,i11,i12,i13,i14]
fig, ax = plt.subplots(1, figsize=(88,60), facecolor="black", edgecolor="black")
for rx in r:
    ax.add_patch(rx)
for ix in i:
    ax.add_artist(ix)

ax.annotate(text='AAPL', xy=(20, 35), color='w', weight='semibold', fontsize=100, ha='center', va='center')
ax.annotate(text='NVDA', xy=(14, 10), color='w', weight='semibold', fontsize=100, ha='center', va='center')
ax.annotate(text='INTC', xy=(30, 17), color='w', weight='semibold', fontsize=100, ha='center', va='center')
ax.annotate(text='QCOM', xy=(30, 8), color='w', weight='semibold', fontsize=90, ha='center', va='center')

ax.annotate(text='MSFT', xy=(50, 43), color='w', weight='semibold', fontsize=100, ha='center', va='center')
ax.annotate(text='GOOGL', xy=(46, 28.5), color='w', weight='semibold', fontsize=90, ha='center', va='center')
ax.annotate(text='FB', xy=(56, 28.5), color='w', weight='semibold', fontsize=80, ha='center', va='center')

ax.annotate(text='AMZN', xy=(46, 9), color='w', weight='semibold', fontsize=80, ha='center', va='center')
ax.annotate(text='WMT', xy=(56, 9), color='w', weight='semibold', fontsize=80, ha='center', va='center')

ax.annotate(text='TSLA', xy=(70, 47.5), color='w', weight='semibold', fontsize=80, ha='center', va='center')
ax.annotate(text='EA', xy=(80, 47.5), color='w', weight='semibold', fontsize=80, ha='center', va='center')

ax.annotate(text='UNH', xy=(74, 25), color='w', weight='semibold', fontsize=100, ha='center', va='center')
ax.annotate(text='AZN', xy=(70, 9), color='w', weight='semibold', fontsize=90, ha='center', va='center')
ax.annotate(text='CVS', xy=(80, 9), color='w', weight='semibold', fontsize=80, ha='center', va='center')

#===============================================================================================================
c = -3
ax.annotate(text=df.loc['AAPL']['percentage_change'], xy=(20, 32), color=get_color('AAPL'), weight='semibold', fontsize=100, ha='center', va='center')
ax.annotate(text=df.loc['NVDA']['percentage_change'], xy=(14, 7), color=get_color('NVDA'), weight='semibold', fontsize=100, ha='center', va='center')
ax.annotate(text=df.loc['INTC']['percentage_change'], xy=(30, 14.3), color=get_color('INTC'), weight='semibold', fontsize=100, ha='center', va='center')
ax.annotate(text=df.loc['QCOM']['percentage_change'], xy=(30, 5.3), color=get_color('QCOM'), weight='semibold', fontsize=90, ha='center', va='center')

ax.annotate(text=df.loc['MSFT']['percentage_change'], xy=(50, 40), color=get_color('MSFT'), weight='semibold', fontsize=100, ha='center', va='center')
ax.annotate(text=df.loc['GOOGL']['percentage_change'], xy=(46, 26), color=get_color('GOOGL'), weight='semibold', fontsize=90, ha='center', va='center')
ax.annotate(text=df.loc['FB']['percentage_change'], xy=(56, 26), color=get_color('FB'), weight='semibold', fontsize=80, ha='center', va='center')

ax.annotate(text=df.loc['AMZN']['percentage_change'], xy=(46, 7), color=get_color('AMZN'), weight='semibold', fontsize=80, ha='center', va='center')
ax.annotate(text=df.loc['WMT']['percentage_change'], xy=(56, 7), color=get_color('WMT'), weight='semibold', fontsize=80, ha='center', va='center')

ax.annotate(text=df.loc['TSLA']['percentage_change'], xy=(70, 45), color=get_color('TSLA'), weight='semibold', fontsize=80, ha='center', va='center')
ax.annotate(text=df.loc['EA']['percentage_change'], xy=(80, 45), color=get_color('EA'), weight='semibold', fontsize=80, ha='center', va='center')

ax.annotate(text=df.loc['UNH']['percentage_change'], xy=(74, 22), color=get_color('UNH'), weight='semibold', fontsize=100, ha='center', va='center')
ax.annotate(text=df.loc['AZN']['percentage_change'], xy=(70, 7), color=get_color('AZN'), weight='semibold', fontsize=90, ha='center', va='center')
ax.annotate(text=df.loc['CVS']['percentage_change'], xy=(80, 7), color=get_color('CVS'), weight='semibold', fontsize=80, ha='center', va='center')

ax.set_xlim(0,88)
ax.set_ylim(0,60)
#plt.grid()
plt.savefig('overview.png', bbox_inches='tight')
plt.show()
# Out:
# time: 5.21 s (started: 2022-05-28 19:41:48 -07:00)

# %%
#ax.annotate(text='INTC', xy=(30, 14), color='w', weight='semibold', fontsize=100, ha='center', va='center')
# Out:
# time: 386 µs (started: 2022-05-28 19:41:54 -07:00)

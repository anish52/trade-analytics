# %% [markdown]
# Install required libs

# %%
pip install alpha_vantage pandas ta pandas-datareader yfinance TACharts
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting alpha_vantage
#   Downloading alpha_vantage-2.3.1-py3-none-any.whl (31 kB)
# Requirement already satisfied: pandas in /Users/Malay/miniconda3/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: ta in /Users/Malay/miniconda3/lib/python3.7/site-packages (0.10.0)
# Collecting pandas-datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: yfinance in /Users/Malay/miniconda3/lib/python3.7/site-packages (0.1.70)
# Collecting TACharts
#   Downloading TAcharts-0.0.29-py3-none-any.whl (34 kB)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-macosx_10_9_x86_64.whl (570 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.9/570.9 kB 9.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests in /Users/Malay/miniconda3/lib/python3.7/site-packages (from alpha_vantage) (2.27.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/Malay/miniconda3/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/Malay/.local/lib/python3.7/site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.17.3 in /Users/Malay/miniconda3/lib/python3.7/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: lxml in /Users/Malay/miniconda3/lib/python3.7/site-packages (from pandas-datareader) (4.8.0)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/Malay/miniconda3/lib/python3.7/site-packages (from yfinance) (0.0.10)
# Requirement already satisfied: matplotlib>=2.0.0 in /Users/Malay/miniconda3/lib/python3.7/site-packages (from TACharts) (3.5.1)
# Requirement already satisfied: cycler>=0.10 in /Users/Malay/miniconda3/lib/python3.7/site-packages (from matplotlib>=2.0.0->TACharts) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/Malay/miniconda3/lib/python3.7/site-packages (from matplotlib>=2.0.0->TACharts) (9.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/Malay/miniconda3/lib/python3.7/site-packages (from matplotlib>=2.0.0->TACharts) (4.33.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/Malay/miniconda3/lib/python3.7/site-packages (from matplotlib>=2.0.0->TACharts) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /Users/Malay/miniconda3/lib/python3.7/site-packages (from matplotlib>=2.0.0->TACharts) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/Malay/miniconda3/lib/python3.7/site-packages (from matplotlib>=2.0.0->TACharts) (1.4.2)
# Requirement already satisfied: six>=1.5 in /Users/Malay/.local/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Malay/.local/lib/python3.7/site-packages (from requests->alpha_vantage) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Malay/miniconda3/lib/python3.7/site-packages (from requests->alpha_vantage) (2022.5.18.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/Malay/miniconda3/lib/python3.7/site-packages (from requests->alpha_vantage) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/Malay/.local/lib/python3.7/site-packages (from requests->alpha_vantage) (1.26.9)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-macosx_10_9_x86_64.whl (35 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-macosx_10_9_x86_64.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.7/120.7 kB 80.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4 in /Users/Malay/miniconda3/lib/python3.7/site-packages (from aiohttp->alpha_vantage) (4.2.0)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-macosx_10_9_x86_64.whl (28 kB)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Users/Malay/miniconda3/lib/python3.7/site-packages (from aiohttp->alpha_vantage) (21.4.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Installing collected packages: multidict, frozenlist, asynctest, async-timeout, yarl, aiosignal, TACharts, pandas-datareader, aiohttp, alpha_vantage
# Successfully installed TACharts-0.0.29 aiohttp-3.8.1 aiosignal-1.2.0 alpha_vantage-2.3.1 async-timeout-4.0.2 asynctest-0.13.0 frozenlist-1.3.0 multidict-6.0.2 pandas-datareader-0.10.0 yarl-1.7.2
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install TAcharts

# %%
import yfinance as yf
import pandas as pd
from ta.utils import dropna
from ta.volatility import BollingerBands
import ta
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
#import seaborn as sns
#import tensorflow as tf
#sns.set() # setting seaborn default for plots
#from sklearn.neighbors import KNeighborsClassifier
#from sklearn.tree import DecisionTreeClassifier
#from sklearn.ensemble import RandomForestClassifier
#from sklearn.naive_bayes import GaussianNB
#from sklearn.svm import SVC
#from sklearn.feature_selection import SelectKBest, f_classif
#from google.colab import files
#from sklearn.model_selection import KFold
#from sklearn.model_selection import cross_val_score
#from pandas_profiling import ProfileReport
#from sklearn.metrics import r2_score, accuracy_score
#from sklearn.model_selection import learning_curve
#from sklearn.model_selection import train_test_split
from matplotlib import style
import datetime as dt1
from datetime import datetime as dt
import plotly.graph_objs as go
#from statsmodels.tsa.seasonal import seasonal_decompose
#import keras
#import keras.backend as K

# %% [markdown]
# Query parameters

# %%
#stock_list = ['AAPL','NVDA']
stock_list = ['AZN','AAPL','NVDA','INTC','QCOM','MSFT','GOOGL','FB','AMZN','WMT','TSLA','EA','UNH','CVS']
window = 26
start_date = "2021-06-01"
end_date = "2022-05-30"
interval='1d'
percent = 2
data = yf.download(stock_list, start=start_date, end=end_date,group_by='ticker', interval=interval)
# Out:
# [*********************100%***********************]  14 of 14 completed

# %%
import TAcharts
from pandas.tseries.offsets import DateOffset

def get_prediction():   
    """
    Get prediction range of future stock predictions for the listed stocks
    Output:
        df1 : pd.dataframe 
    """     
    df1 = yf.download("AAPL", start=start_date, end=end_date,group_by='ticker', interval=interval)
    df1 = df1.drop(columns=['Close',"High","Low","Open","Adj Close","Volume"])
    # area plots of share price per stock
    for stk in stock_list:
        df1[stk] = data[stk]["Adj Close"]
        df1[stk+"A"] = float('NaN')
        df1[stk+"B"] = float('NaN')
    tmp = {}
    # area plots of share price per stock
    fig = go.Figure()
    off_date = df1.index[-1]
    for stk in stock_list:
        df = data[stk]
        df = df.drop(columns=['Close'])
        df.index.names = ['date']
        df.reset_index(inplace=True)
        df=df.rename(columns={'Open': 'open', 'High': 'high'})
        df=df.rename(columns={'Low': 'low', 'Adj Close': 'close'})
        df=df.rename(columns={'Volume': 'volume'})
        i = TAcharts.indicators.Ichimoku(df)
    
        i.build(9,26,52,26);
    
    
        l = len(df["close"])
        if i.ichimoku["senkou_a"][l] > i.ichimoku["senkou_b"][l]:
            mid =i.ichimoku["senkou_b"][l] +  (i.ichimoku["senkou_a"][l] - i.ichimoku["senkou_b"][l] ) /2
        else:
            mid =i.ichimoku["senkou_a"][l]  + (i.ichimoku["senkou_b"][l] - i.ichimoku["senkou_a"][l] ) /2
        
        if mid > df["close"][len(df["close"])-1]:
            deltaa =  mid - df["close"][len(df["close"])-1]
            deltab =  mid - df["close"][len(df["close"])-1]        
        else:
            deltaa =  mid - df["close"][len(df["close"])-1]
            deltab =  mid - df["close"][len(df["close"])-1]   
        #print(mid,deltaa,deltab)
                                                           
        for j in range(26):
            i.ichimoku["senkou_a"][l+j] -= deltaa 
            i.ichimoku["senkou_b"][l+j] -= deltab 
    
        for j in range(l-79):
            i.ichimoku["senkou_b"][j+79] = float('NaN')
        #print(i.ichimoku)
        df['A'] = 0
        df['B'] = 0
    
        for j in range(26):
            if off_date+DateOffset(days=j+1) in tmp:
                tmp[off_date+DateOffset(days=j+1)].append(float('NaN'))
                tmp[off_date+DateOffset(days=j+1)].append(i.ichimoku["senkou_a"][l+j])
                tmp[off_date+DateOffset(days=j+1)].append(i.ichimoku["senkou_b"][l+j])
            else:
                tmp[off_date+DateOffset(days=j+1)] = [float('NaN'), i.ichimoku["senkou_a"][l+j],i.ichimoku["senkou_b"][l+j] ]
    for t in tmp:
        df1.loc[t] = tmp[t]   
    return df1

# %%
def fillcol(label):
    """
    Fill Color
    """
    if label == 0:
        return 'rgba(0,250,0,0.4)'
    else:
        return 'rgba(0,250,250,0.4)'
def plot_pred(df1):    
    """
    Plot of future stock predictions for the listed stocks
    Input:
        df1 : pd.dataframe 
    Output:
        fig : FigureWidget
    """    
    fig = go.Figure()
    for stock in stock_list:
        fig.add_trace(
            go.Scatter(
                x=df1.index,
                y=df1[stock],
                mode='lines',
                #fill='tozeroy',
                hovertemplate = 'Stock: {}'.format(stock) + '<br>Date: %{x} </br>Price: %{y:$.2f}<extra></extra>',
            )
        )

        df1[stock +'label'] = np.where(df1[stock+"A"][-1]<df1[stock+"B"][-1], 1, 0)
        #print(stock,df1[stock +'label'].iloc[0])
        fig.add_traces(go.Scatter(x=df1.index, y = df1[stock+"A"],
                                  line = dict(color='rgba(0,0,0,0)'),
                                  hovertemplate = 'Lower limit: {}'.format(stock) + '<br>Date: %{x} </br>Price: %{y:$.2f}<extra></extra>',
    
                                 ))
        
        fig.add_traces(go.Scatter(x=df1.index, y = df1[stock+"B"],
                                  line = dict(color='rgba(0,0,0,0)'),
                                  fill='tonexty', 
                                  hovertemplate = 'Upper limit: {}'.format(stock) + '<br>Date: %{x} </br>Price: %{y:$.2f}<extra></extra>',
                                  
                                  fillcolor = fillcol(df1[stock +'label'].iloc[0])))  
        
    # layout for x axis and range slider/selector

    # layout for dropdown menu to select stock
    buttons_list = []
    buttons_list.append(
                dict(label="All",
                     method="update",
                     args=[{"visible": [True] * len(stock_list)},
                           {"title": "PROJECTED DAILY SHARE PRICE"}])
        )
    for ind, stock in enumerate(stock_list):
        visible_list = [False] * len(stock_list) *3
        
        visible_list[3 *ind] = True
        visible_list[3 *ind+1] = True
        visible_list[3 *ind+2] = True
        buttons_list.append(
                    dict(label=stock,
                         method="update",
                         args=[{"visible": visible_list},
                               {"title": '{} : PROJECTED DAILY SHARE PRICE'.format(stock)}])
        )
    
    # add dropdown menu and update fig layout
    fig.update_layout(
        showlegend = False,
        updatemenus=[
            dict(
                active=0,
                buttons=buttons_list,
                bgcolor='rgb(179,226,205)',
                x=-.15,
                y=.9
            ),
        ],
        paper_bgcolor='rgba(37,37,37,1)',
        plot_bgcolor='rgba(37,37,37,1)',
        font_color='gray',
        title_font_color='white',
        title_font_size=22,
        title_font_family='Droid Serif',
        title = {'text':'PROJECTED DAILY SHARE PRICE',
                 'y':0.95,
                 'x':0.025,
                 'xanchor': 'left',
                 'yanchor': 'top'
                },
        hovermode='x unified'
    )
    
    fig.update_layout(
        annotations=[
            dict(text="Select Stock:", x=-.26, xref="paper", y=1, yref="paper",
                                 align="left", showarrow=False, font_color='white')
        ])
    
    #fig.show()
    return go.FigureWidget(fig)

# %%
pred_df = get_prediction()
pred_plot = plot_pred(pred_df)
# Out:
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/vp/81z4k0ld3bjfws85wfgk07n80000gn/T/ipykernel_51508/4136280917.py in <module>
# ----> 1 pred_df = get_prediction()
#       2 pred_plot = plot_pred(pred_df)
#
# /var/folders/vp/81z4k0ld3bjfws85wfgk07n80000gn/T/ipykernel_51508/2195743836.py in get_prediction()
#      29         i = TAcharts.indicators.Ichimoku(df)
#      30
# ---> 31         i.build(9,26,52,26);
#      32
#      33
#
# ~/miniconda3/lib/python3.7/site-packages/TAcharts/indicators/ichimoku.py in build(self, tenkan_interval, kijun_interval, senkou_b_interval, displacement)
#      88         # Tenkan (conversion line) = (highest high + highest low)/2 for the past x intervals
#      89         # Kijun (base line) = (highest high + lowest low)/2 for the past x*3 intervals
# ---> 90         self._build_lines(tenkan=tenkan_interval, kijun=kijun_interval)
#      91
#      92         # Chikou (lagging span) = Current closing price time-shifted backwards x*3 intervals
#
# ~/miniconda3/lib/python3.7/site-packages/TAcharts/indicators/ichimoku.py in _build_lines(self, **kwargs)
#      56     def _build_lines(self, **kwargs):
#      57         for key, val in kwargs.items():
# ---> 58             high = sma(self.df["high"], val, "max")
#      59             low = sma(self.df["low"], val, "min")
#      60             self.ichimoku[key] = (high + low) / 2
#
# ~/miniconda3/lib/python3.7/site-packages/TAcharts/wrappers.py in wrapper(*args, **kwargs)
#      32
#      33         args = tuple(x if type(x) != pd.Series else args[0].to_numpy(na_value=0) for x in args)
# ---> 34         if oldSeries:
#      35             return pd.Series(data=fn(*args, **kwargs), index=oldSeries.index)
#      36         else:
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1536     def __nonzero__(self):
#    1537         raise ValueError(
# -> 1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1540         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
pred_plot

# %%
stock_list = ['AAPL','NVDA','INTC','QCOM','MSFT','GOOGL','FB','AMZN','WMT','TSLA','EA','UNH','AZN','CVS']
stock_list = ['AAPL','GOOG']
stock = "NVDA"
window = 7
start_date = "2021-06-01"
end_date = "2022-05-29"
interval='1d'
percent = 2
import TAcharts
from TAcharts.utils.ohlcv import OHLCV
data1 = yf.download(stock, start=start_date, end=end_date,group_by='column', interval=interval)
data1
data1 = data1.drop(columns=['Adj Close'])
data1.index.names = ['date']
data1.reset_index(inplace=True)
data1 = data1.rename(columns={'Open': 'open', 'High': 'high'})
data1 = data1.rename(columns={'Low': 'low', 'Close': 'close'})

data1 = data1.rename(columns={'Volume': 'volume'})
i = TAcharts.indicators.Ichimoku(data1)

i.build(9,26,52,26);
i.plot()        

len(i.ichimoku["senkou_b"])
a = {}
b = {}
l = len(data1["close"])
if i.ichimoku["senkou_a"][l] > data1["close"][len(data1["close"])-1]:
    deltaa =  i.ichimoku["senkou_a"][l] - data1["close"][len(data1["close"])-1]
if i.ichimoku["senkou_a"][l] <= data1["close"][len(data1["close"])-1]:
    deltaa = i.ichimoku["senkou_a"][l] - data1["close"][len(data1["close"])-1]                                                         
if i.ichimoku["senkou_b"][l] > data1["close"][len(data1["close"])-1]:
    deltab =  i.ichimoku["senkou_b"][l] - data1["close"][len(data1["close"])-1]
if i.ichimoku["senkou_b"][l] <= data1["close"][len(data1["close"])-1]:
    deltab = i.ichimoku["senkou_b"][l] - data1["close"][len(data1["close"])-1]

                                                       
for j in range(26):
        i.ichimoku["senkou_a"][l+j] -= deltaa 
        i.ichimoku["senkou_b"][l+j] -= deltab 

for j in range(l-79):
       i.ichimoku["senkou_b"][j+79] = float('NaN')
